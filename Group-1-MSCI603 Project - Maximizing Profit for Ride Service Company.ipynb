# %% [markdown]
# # Setting up the model
# ## "pip install gekko" in order to use this Python package

# %%
# Importing GEKKO package
from gekko import GEKKO

# %%
# Create GEKKO model
m = GEKKO() # note that if the solution isn't running due to server issues, try m = GEKKO(remote=False) to run locally.

# %%
# Calls for the solver APOPT, which is appropriate for a mixed-integer nonlinear solution such as this model

m.options.SOLVER = 1

# %% [markdown]
# # Decision Variables

# %% [markdown]
# ### Minimum number of cars the company needs for each class to run the business

# %%
# Compact class vehicles in company
x_bmw_compact = m.Var(lb=0, integer = True)
x_audi_compact = m.Var(lb=0, integer = True)
x_hyundai_compact = m.Var(lb=0, integer = True)
x_mercedes_compact = m.Var(lb=0, integer = True)
x_honda_compact = m.Var(lb=0, integer = True)
x_acura_compact = m.Var(lb=0, integer = True)
x_lexus_compact = m.Var(lb=0, integer = True)
x_volkswagen_compact = m.Var(lb=0, integer = True)
x_mazda_compact = m.Var(lb=0, integer = True)
x_nissan_compact = m.Var(lb=0, integer = True)
x_kia_compact = m.Var(lb=0, integer = True)
x_volvo_compact = m.Var(lb=0, integer = True)
x_chevrolet_compact = m.Var(lb=0, integer = True)
x_subaru_compact = m.Var(lb=0, integer = True)
x_toyota_compact = m.Var(lb=0, integer = True)

# Mid-size class vehicles in company
x_audi_midsize = m.Var(lb=0, integer = True)
x_honda_midsize = m.Var(lb=0, integer = True)
x_hyundai_midsize = m.Var(lb=0, integer = True)
x_kia_midsize = m.Var(lb=0, integer = True)
x_ford_midsize = m.Var(lb=0, integer = True)
x_subaru_midsize = m.Var(lb=0, integer = True)
x_mazda_midsize = m.Var(lb=0, integer = True)
x_volkswagen_midsize = m.Var(lb=0, integer = True)
x_toyota_midsize = m.Var(lb=0, integer = True)
x_acura_midsize = m.Var(lb=0, integer = True)
x_volvo_midsize = m.Var(lb=0, integer = True)
x_nissan_midsize = m.Var(lb=0, integer = True)
x_lexus_midsize = m.Var(lb=0, integer = True)

# SUVs in company
x_honda_suv= m.Var(lb=0, integer = True)
x_subaru_suv= m.Var(lb=0, integer = True)
x_mazda_suv= m.Var(lb=0, integer = True)
x_ford_suv= m.Var(lb=0, integer = True)
x_kia_suv= m.Var(lb=0, integer = True)
x_hyundai_suv= m.Var(lb=0, integer = True)
x_acura_suv= m.Var(lb=0, integer = True)
x_lexus_suv= m.Var(lb=0, integer = True)
x_audi_suv= m.Var(lb=0, integer = True)
x_toyota_suv= m.Var(lb=0, integer = True)
x_nissan_suv= m.Var(lb=0, integer = True)
x_gmc_suv= m.Var(lb=0, integer = True)
x_volkswagen_suv= m.Var(lb=0, integer = True)
x_bmw_suv= m.Var(lb=0, integer = True)
x_volvo_suv= m.Var(lb=0, integer = True)

# %% [markdown]
# ### Distance each car with model i in class j should be driven in order to maximize profit

# %%
# Distance car i class compact drives per year
d_bmw_compact = m.Var(lb=0)
d_audi_compact = m.Var(lb=0)
d_hyundai_compact = m.Var(lb=0)
d_mercedes_compact = m.Var(lb=0)
d_honda_compact = m.Var(lb=0)
d_acura_compact = m.Var(lb=0)
d_lexus_compact = m.Var(lb=0)
d_volkswagen_compact = m.Var(lb=0)
d_mazda_compact = m.Var(lb=0)
d_nissan_compact = m.Var(lb=0)
d_kia_compact = m.Var(lb=0)
d_volvo_compact = m.Var(lb=0)
d_chevrolet_compact = m.Var(lb=0)
d_subaru_compact = m.Var(lb=0)
d_toyota_compact = m.Var(lb=0)

# Distance car i class mid-size drives per year
d_audi_midsize = m.Var(lb=0)
d_honda_midsize = m.Var(lb=0)
d_hyundai_midsize = m.Var(lb=0)
d_kia_midsize = m.Var(lb=0)
d_ford_midsize = m.Var(lb=0)
d_subaru_midsize = m.Var(lb=0)
d_mazda_midsize = m.Var(lb=0)
d_volkswagen_midsize = m.Var(lb=0)
d_toyota_midsize = m.Var(lb=0)
d_acura_midsize = m.Var(lb=0)
d_volvo_midsize = m.Var(lb=0)
d_nissan_midsize = m.Var(lb=0)
d_lexus_midsize = m.Var(lb=0)

# Distance car i class SUV drives per year
d_honda_suv= m.Var(lb=0)
d_subaru_suv= m.Var(lb=0)
d_mazda_suv= m.Var(lb=0)
d_ford_suv= m.Var(lb=0)
d_kia_suv= m.Var(lb=0)
d_hyundai_suv= m.Var(lb=0)
d_acura_suv= m.Var(lb=0)
d_lexus_suv= m.Var(lb=0)
d_audi_suv= m.Var(lb=0)
d_toyota_suv= m.Var(lb=0)
d_nissan_suv= m.Var(lb=0)
d_gmc_suv= m.Var(lb=0)
d_volkswagen_suv= m.Var(lb=0)
d_bmw_suv= m.Var(lb=0)
d_volvo_suv= m.Var(lb=0)

# %% [markdown]
# ### Binary Variable. 1 = There is at least one of the car with model i in class j leased. 0 otherwise.

# %%
# If car i class compact purchased
y_bmw_compact = m.Var(integer=True,lb=0,ub=1)
y_audi_compact = m.Var(integer=True,lb=0,ub=1)
y_hyundai_compact = m.Var(integer=True,lb=0,ub=1)
y_mercedes_compact = m.Var(integer=True,lb=0,ub=1)
y_honda_compact = m.Var(integer=True,lb=0,ub=1)
y_acura_compact = m.Var(integer=True,lb=0,ub=1)
y_lexus_compact = m.Var(integer=True,lb=0,ub=1)
y_volkswagen_compact = m.Var(integer=True,lb=0,ub=1)
y_mazda_compact = m.Var(integer=True,lb=0,ub=1)
y_nissan_compact = m.Var(integer=True,lb=0,ub=1)
y_kia_compact = m.Var(integer=True,lb=0,ub=1)
y_volvo_compact = m.Var(integer=True,lb=0,ub=1)
y_chevrolet_compact = m.Var(integer=True,lb=0,ub=1)
y_subaru_compact = m.Var(integer=True,lb=0,ub=1)
y_toyota_compact = m.Var(integer=True,lb=0,ub=1)

# If car i class mid-size purchased
y_audi_midsize = m.Var(integer=True,lb=0,ub=1)
y_honda_midsize = m.Var(integer=True,lb=0,ub=1)
y_hyundai_midsize = m.Var(integer=True,lb=0,ub=1)
y_kia_midsize = m.Var(integer=True,lb=0,ub=1)
y_ford_midsize = m.Var(integer=True,lb=0,ub=1)
y_subaru_midsize = m.Var(integer=True,lb=0,ub=1)
y_mazda_midsize = m.Var(integer=True,lb=0,ub=1)
y_volkswagen_midsize = m.Var(integer=True,lb=0,ub=1)
y_toyota_midsize = m.Var(integer=True,lb=0,ub=1)
y_acura_midsize = m.Var(integer=True,lb=0,ub=1)
y_volvo_midsize = m.Var(integer=True,lb=0,ub=1)
y_nissan_midsize = m.Var(integer=True,lb=0,ub=1)
y_lexus_midsize = m.Var(integer=True,lb=0,ub=1)

# If car i class suv purchased
y_honda_suv= m.Var(integer=True,lb=0,ub=1)
y_subaru_suv= m.Var(integer=True,lb=0,ub=1)
y_mazda_suv= m.Var(integer=True,lb=0,ub=1)
y_ford_suv= m.Var(integer=True,lb=0,ub=1)
y_kia_suv= m.Var(integer=True,lb=0,ub=1)
y_hyundai_suv= m.Var(integer=True,lb=0,ub=1)
y_acura_suv= m.Var(integer=True,lb=0,ub=1)
y_lexus_suv= m.Var(integer=True,lb=0,ub=1)
y_audi_suv= m.Var(integer=True,lb=0,ub=1)
y_toyota_suv= m.Var(integer=True,lb=0,ub=1)
y_nissan_suv= m.Var(integer=True,lb=0,ub=1)
y_gmc_suv= m.Var(integer=True,lb=0,ub=1)
y_volkswagen_suv= m.Var(integer=True,lb=0,ub=1)
y_bmw_suv= m.Var(integer=True,lb=0,ub=1)
y_volvo_suv= m.Var(integer=True,lb=0,ub=1)

# %% [markdown]
# ### Parameter Variables (some may not be used)

# %%
# Distance 
distance = d_bmw_compact + d_audi_compact + d_hyundai_compact + d_mercedes_compact + d_honda_compact + d_acura_compact + d_lexus_compact + d_volkswagen_compact + d_mazda_compact + d_nissan_compact + d_kia_compact + d_volvo_compact + d_chevrolet_compact + d_subaru_compact + d_toyota_compact + d_audi_midsize + d_honda_midsize + d_hyundai_midsize + d_kia_midsize + d_ford_midsize + d_subaru_midsize + d_mazda_midsize + d_volkswagen_midsize + d_toyota_midsize + d_acura_midsize + d_volvo_midsize + d_nissan_midsize + d_lexus_midsize + d_honda_suv + d_subaru_suv + d_mazda_suv + d_ford_suv + d_kia_suv + d_hyundai_suv + d_acura_suv + d_lexus_suv + d_audi_suv + d_toyota_suv + d_nissan_suv + d_gmc_suv + d_volkswagen_suv + d_bmw_suv + d_volvo_suv

dcompact = d_bmw_compact + d_audi_compact + d_hyundai_compact + d_mercedes_compact + d_honda_compact + d_acura_compact + d_lexus_compact + d_volkswagen_compact + d_mazda_compact + d_nissan_compact + d_kia_compact + d_volvo_compact + d_chevrolet_compact + d_subaru_compact + d_toyota_compact

dmidsize = d_audi_midsize + d_honda_midsize + d_hyundai_midsize + d_kia_midsize + d_ford_midsize + d_subaru_midsize + d_mazda_midsize + d_volkswagen_midsize + d_toyota_midsize + d_acura_midsize + d_volvo_midsize + d_nissan_midsize + d_lexus_midsize 

dsuv = d_honda_suv + d_subaru_suv + d_mazda_suv + d_ford_suv + d_kia_suv + d_hyundai_suv + d_acura_suv + d_lexus_suv + d_audi_suv + d_toyota_suv + d_nissan_suv + d_gmc_suv + d_volkswagen_suv + d_bmw_suv + d_volvo_suv


# CO2 Emission
emission = 0.205*d_bmw_compact*x_bmw_compact + 0.182*d_audi_compact*x_audi_compact + 0.160*d_hyundai_compact*x_hyundai_compact + 0.219*d_mercedes_compact*x_mercedes_compact + 0.151*d_honda_compact*x_honda_compact + 0.199*d_acura_compact*x_acura_compact + 0.254*d_lexus_compact*x_lexus_compact + 0.162*d_volkswagen_compact*x_volkswagen_compact + 0.181*d_mazda_compact*x_mazda_compact + 0.217*d_nissan_compact*x_nissan_compact + 0.151*d_kia_compact*x_kia_compact + 0.208*d_volvo_compact*x_volvo_compact + 0.167*d_chevrolet_compact*x_chevrolet_compact + 0.236*d_subaru_compact*x_subaru_compact + 0.155*d_toyota_compact*x_toyota_compact + 0.205*d_audi_midsize*x_audi_midsize + 0.165*d_honda_midsize*x_honda_midsize + 0.192*d_hyundai_midsize*x_hyundai_midsize + 0.184*d_kia_midsize*x_kia_midsize + 0.203*d_ford_midsize*x_ford_midsize + 0.174*d_subaru_midsize*x_subaru_midsize + 0.181*d_mazda_midsize*x_mazda_midsize + 0.205*d_volkswagen_midsize*x_volkswagen_midsize + 0.106*d_toyota_midsize*x_toyota_midsize + 0.196*d_acura_midsize*x_acura_midsize + 0.223*d_volvo_midsize*x_volvo_midsize + 0.167*d_nissan_midsize*x_nissan_midsize + 0.168*d_lexus_midsize*x_lexus_midsize + 0.162*d_honda_suv*x_honda_suv + 0.185*d_subaru_suv*x_subaru_suv + 0.189*d_mazda_suv*x_mazda_suv + 0.229*d_ford_suv*x_ford_suv + 0.190*d_kia_suv*x_kia_suv + 0.187*d_hyundai_suv*x_hyundai_suv + 0.254*d_acura_suv*x_acura_suv + 0.226*d_lexus_suv*x_lexus_suv + 0.248*d_audi_suv*x_audi_suv + 0.184*d_toyota_suv*x_toyota_suv + 0.192*d_nissan_suv*x_nissan_suv + 0.202*d_gmc_suv*x_gmc_suv + 0.221*d_volkswagen_suv*x_volkswagen_suv + 0.213*d_bmw_suv*x_bmw_suv + 0.210*d_volvo_suv*x_volvo_suv

# if compact purchased
ycompact = y_bmw_compact + y_audi_compact + y_hyundai_compact + y_mercedes_compact + y_honda_compact + y_acura_compact + y_lexus_compact + y_volkswagen_compact + y_mazda_compact + y_nissan_compact + y_kia_compact + y_volvo_compact + y_chevrolet_compact + y_subaru_compact + y_toyota_compact

# if mid-size purchased
ymidsize = y_audi_midsize + y_honda_midsize + y_hyundai_midsize + y_kia_midsize + y_ford_midsize + y_subaru_midsize + y_mazda_midsize + y_volkswagen_midsize + y_toyota_midsize + y_acura_midsize + y_volvo_midsize + y_nissan_midsize + y_lexus_midsize 

# if SUV purchased
ysuv = y_honda_suv + y_subaru_suv + y_mazda_suv + y_ford_suv + y_kia_suv + y_hyundai_suv + y_acura_suv + y_lexus_suv + y_audi_suv + y_toyota_suv + y_nissan_suv + y_gmc_suv + y_volkswagen_suv + y_bmw_suv + y_volvo_suv

# x variables
cars = x_bmw_compact + x_audi_compact + x_hyundai_compact + x_mercedes_compact + x_honda_compact + x_acura_compact + x_lexus_compact + x_volkswagen_compact + x_mazda_compact + x_nissan_compact + x_kia_compact + x_volvo_compact + x_chevrolet_compact + x_subaru_compact + x_toyota_compact + x_audi_midsize + x_honda_midsize + x_hyundai_midsize + x_kia_midsize + x_ford_midsize + x_subaru_midsize + x_mazda_midsize + x_volkswagen_midsize + x_toyota_midsize + x_acura_midsize + x_volvo_midsize + x_nissan_midsize + x_lexus_midsize + x_honda_suv + x_subaru_suv + x_mazda_suv + x_ford_suv + x_kia_suv + x_hyundai_suv + x_acura_suv + x_lexus_suv + x_audi_suv + x_toyota_suv + x_nissan_suv + x_gmc_suv + x_volkswagen_suv + x_bmw_suv + x_volvo_suv

# number of compact vehicles the company wants to lease
xcompact = x_bmw_compact + x_audi_compact + x_hyundai_compact + x_mercedes_compact + x_honda_compact + x_acura_compact + x_lexus_compact + x_volkswagen_compact + x_mazda_compact + x_nissan_compact + x_kia_compact + x_volvo_compact + x_chevrolet_compact + x_subaru_compact + x_toyota_compact

# number of mid-size vehicles the company wants to lease
xmidsize = x_audi_midsize + x_honda_midsize + x_hyundai_midsize + x_kia_midsize + x_ford_midsize + x_subaru_midsize + x_mazda_midsize + x_volkswagen_midsize + x_toyota_midsize + x_acura_midsize + x_volvo_midsize + x_nissan_midsize + x_lexus_midsize  

# number of SUVs the company wants to lease
xsuv = x_honda_suv + x_subaru_suv + x_mazda_suv + x_ford_suv + x_kia_suv + x_hyundai_suv + x_acura_suv + x_lexus_suv + x_audi_suv + x_toyota_suv + x_nissan_suv + x_gmc_suv + x_volkswagen_suv + x_bmw_suv + x_volvo_suv

# %% [markdown]
# ### Formulas

# %%
# Costs
leasing_cost = 8844*x_bmw_compact + 5742.84*x_audi_compact + 2684.16*x_hyundai_compact + 6201.24*x_mercedes_compact + 3435.84*x_honda_compact* + 5203.56*x_acura_compact* + 2848.92*x_lexus_compact + 3114.6*x_volkswagen_compact + 3630.24*x_mazda_compact + 3180*x_nissan_compact + 3058.44*x_kia_compact + 5703.6*x_volvo_compact + 3612*x_chevrolet_compact + 4852.8*x_subaru_compact + 2655.96*x_toyota_compact + 8998.44*x_audi_midsize + 3012.96*x_honda_midsize + 2387.04*x_hyundai_midsize + 3112.32*x_kia_midsize + 5196*x_ford_midsize + 4160.76*x_subaru_midsize + 3766.32*x_mazda_midsize + 4371*x_volkswagen_midsize + 4277.88*x_toyota_midsize + 14341.92*x_acura_midsize + 8780.4*x_volvo_midsize + 2616*x_nissan_midsize + 5578.92*x_lexus_midsize + 4025.28*x_honda_suv + 4650.72*x_subaru_suv + 4127.04*x_mazda_suv + 6360*x_ford_suv + 4056.36*x_kia_suv + 3173.16*x_hyundai_suv + 7923.48*x_acura_suv + 5828.16*x_lexus_suv + 8148*x_audi_suv + 4160.76*x_toyota_suv + 4452*x_nissan_suv + 8412*x_gmc_suv + 4677.6*x_volkswagen_suv + 6924*x_bmw_suv + 5469.6*x_volvo_suv

fuel_cost = 1.22*0.0885*d_bmw_compact*x_bmw_compact + 0.92*0.0777*d_audi_compact*x_audi_compact + 0.92*0.0672*d_hyundai_compact*x_hyundai_compact + 1.22*0.0934*d_mercedes_compact*x_mercedes_compact* + 0.92*0.0651*d_honda_compact*x_honda_compact + 1.22*0.0860*d_acura_compact*x_acura_compact + 1.22*0.1086*d_lexus_compact*x_lexus_compact  + 0.92*0.0695*d_volkswagen_compact*x_volkswagen_compact + 0.92*0.0767*d_mazda_compact*x_mazda_compact + 0.92*0.0925*d_nissan_compact*x_nissan_compact + 0.92*0.0662*d_kia_compact*x_kia_compact + 1.22*0.0897*d_volvo_compact*x_volvo_compact + 0.92*0.0714*d_chevrolet_compact*x_chevrolet_compact + 1.22*0.1004*d_subaru_compact*x_subaru_compact + 0.92*0.0667*d_toyota_compact*x_toyota_compact + 1.22*0.0879*d_audi_midsize*x_audi_midsize + 0.92*0.0708*d_honda_midsize*x_honda_midsize + 0.92*0.0805*d_hyundai_midsize*x_hyundai_midsize + 0.92*0.0776*d_kia_midsize*x_kia_midsize + 0.92*0.0865*d_ford_midsize*x_ford_midsize + 0.92*0.0745*d_subaru_midsize*x_subaru_midsize + 0.92*0.0776*d_mazda_midsize*x_mazda_midsize + 0.92*0.0872*d_volkswagen_midsize*x_volkswagen_midsize + 0.92*0.0454*d_toyota_midsize*x_toyota_midsize + 1.22*0.0831*d_acura_midsize*x_acura_midsize + 1.22*0.0959*d_volvo_midsize*x_volvo_midsize + 0.92*0.0710*d_nissan_midsize*x_nissan_midsize + 0.92*0.0724*d_lexus_midsize*x_lexus_midsize + 0.92*0.0694*d_honda_suv*x_honda_suv + 0.92*0.0783*d_subaru_suv*x_subaru_suv + 0.92*0.0809*d_mazda_suv*x_mazda_suv + 0.92*0.0981*d_ford_suv*x_ford_suv + 0.92*0.0800*d_kia_suv*x_kia_suv + 0.92*0.0788*d_hyundai_suv*x_hyundai_suv + 1.22*0.1091*d_acura_suv*x_acura_suv + 1.22*0.0971*d_lexus_suv*x_lexus_suv + 0.92*0.1064*d_audi_suv*x_audi_suv + 0.92*0.0790*d_toyota_suv*x_toyota_suv + 0.92*0.0820*d_nissan_suv*x_nissan_suv + 0.92*0.0820*d_gmc_suv*x_gmc_suv + 0.92*0.0942*d_volkswagen_suv*x_volkswagen_suv + 1.22*0.0913*d_bmw_suv*x_bmw_suv + 0.92*0.0899*d_volvo_suv*x_volvo_suv

# Revenue
revenue = 1*d_bmw_compact*x_bmw_compact + 1*d_audi_compact*x_audi_compact + 1*d_hyundai_compact*x_hyundai_compact + 1*d_mercedes_compact*x_mercedes_compact + 1*d_honda_compact*x_honda_compact* + 1*d_acura_compact*x_acura_compact + 1*d_lexus_compact*x_lexus_compact + 1*d_volkswagen_compact*x_volkswagen_compact + 1*d_mazda_compact*x_mazda_compact + 1*d_nissan_compact*x_nissan_compact + 1*d_kia_compact*x_kia_compact + 1*d_volvo_compact*x_volvo_compact + 1*d_chevrolet_compact*x_chevrolet_compact + 1*d_subaru_compact*x_subaru_compact + 1*d_toyota_compact*x_toyota_compact + 1.2*d_audi_midsize*x_audi_midsize + 1.2*d_honda_midsize*x_honda_midsize + 1.2*d_hyundai_midsize*x_hyundai_midsize + 1.2*d_kia_midsize*x_kia_midsize + 1.2*d_ford_midsize*x_ford_midsize + 1.2*d_subaru_midsize*x_subaru_midsize + 1.2*d_mazda_midsize*x_mazda_midsize + 1.2*d_volkswagen_midsize*x_volkswagen_midsize + 1.2*d_toyota_midsize*x_toyota_midsize + 1.2*d_acura_midsize*x_acura_midsize + 1.2*d_volvo_midsize*x_volvo_midsize + 1.2*d_nissan_midsize*x_nissan_midsize + 1.2*d_lexus_midsize*x_lexus_midsize + 1.5*d_honda_suv*x_honda_suv + 1.5*d_subaru_suv*x_subaru_suv + 1.5*d_mazda_suv*x_mazda_suv + 1.5*d_ford_suv*x_ford_suv + 1.5*d_kia_suv*x_kia_suv + 1.5*d_hyundai_suv*x_hyundai_suv + 1.5*d_acura_suv*x_acura_suv + 1.5*d_lexus_suv*x_lexus_suv + 1.5*d_audi_suv*x_audi_suv + 1.5*d_toyota_suv*x_toyota_suv + 1.5*d_nissan_suv*x_nissan_suv + 1.5*d_gmc_suv*x_gmc_suv + 1.5*d_volkswagen_suv*x_volkswagen_suv + 1.5*d_bmw_suv*x_bmw_suv + 1.5*d_volvo_suv*x_volvo_suv

# Salary
salary = ((28500*cars) + (0.2*revenue))

# Total cost
cost = (leasing_cost) + (fuel_cost) + (salary)

# Profit
profit = (revenue) - (cost)

# %% [markdown]
# # Constraints

# %% [markdown]
# #### Current constraint settings are for the base model. The values were changed accordingly to different scenarios.

# %%
# Add constraints

# CO2 emission limitation to 500,000 kg
m.Equation(emission <= 500000)

# Minimum number of compact cars the company needs to run the business
# Read as "xcompact >=20" or "at least 20 compact cars must be leased."
m.Equation(-xcompact <= -20)

# Minimum number of mid-size cars the company needs to run the business
m.Equation(-xmidsize <= -15)

# Minimum number of SUVs the company needs to run the business
m.Equation(-xsuv <= -20)


# Limit each type of car to 5
m.Equation(x_bmw_compact <= 5)
m.Equation(x_audi_compact <= 5)  
m.Equation(x_hyundai_compact <= 5)
m.Equation(x_mercedes_compact <= 5)
m.Equation(x_honda_compact <= 5)
m.Equation(x_acura_compact <= 5)
m.Equation(x_lexus_compact <= 5)
m.Equation(x_volkswagen_compact <= 5)
m.Equation(x_mazda_compact <= 5)
m.Equation(x_nissan_compact <= 5) 
m.Equation(x_kia_compact <= 5)
m.Equation(x_volvo_compact<= 5)
m.Equation(x_chevrolet_compact <= 5)
m.Equation(x_subaru_compact <= 5)
m.Equation(x_toyota_compact <= 5)
m.Equation(x_audi_midsize <= 5)
m.Equation(x_honda_midsize <= 5)
m.Equation(x_hyundai_midsize <= 5)
m.Equation(x_kia_midsize <= 5)
m.Equation(x_ford_midsize <= 5)
m.Equation(x_subaru_midsize <= 5)
m.Equation(x_mazda_midsize <= 5)
m.Equation(x_volkswagen_midsize <= 5)
m.Equation(x_toyota_midsize <= 5)
m.Equation(x_acura_midsize <= 5)
m.Equation(x_volvo_midsize <= 5)
m.Equation(x_nissan_midsize <= 5)
m.Equation(x_lexus_midsize <= 5)
m.Equation(x_honda_suv <= 5) 
m.Equation(x_subaru_suv <= 5)
m.Equation(x_mazda_suv <= 5)
m.Equation(x_ford_suv <= 5)
m.Equation(x_kia_suv <= 5)
m.Equation(x_hyundai_suv <= 5)
m.Equation(x_acura_suv <= 5)
m.Equation(x_lexus_suv <= 5)
m.Equation(x_audi_suv <= 5)
m.Equation(x_toyota_suv <= 5)
m.Equation(x_nissan_suv <= 5)
m.Equation(x_gmc_suv <= 5)
m.Equation(x_volkswagen_suv <= 5)
m.Equation(x_bmw_suv <= 5)
m.Equation(x_volvo_suv <= 5)


# When number is other than 0 for x, then y will be 1. 0 otherwise. M is any large number.
m.Equation(x_bmw_compact <= 90000*y_bmw_compact)
m.Equation(x_audi_compact <= 90000*y_audi_compact)
m.Equation(x_hyundai_compact <= 90000*y_hyundai_compact)
m.Equation(x_mercedes_compact <= 90000*y_mercedes_compact)
m.Equation(x_honda_compact <= 90000*y_honda_compact)
m.Equation(x_acura_compact <= 90000*y_acura_compact)
m.Equation(x_lexus_compact <= 90000*y_lexus_compact)
m.Equation(x_volkswagen_compact <= 90000*y_volkswagen_compact)
m.Equation(x_mazda_compact <= 90000* y_mazda_compact)
m.Equation(x_nissan_compact <= 90000* y_nissan_compact)
m.Equation(x_kia_compact <= 90000*y_kia_compact)
m.Equation(x_volvo_compact <= 90000*y_volvo_compact)
m.Equation(x_chevrolet_compact <= 90000*y_chevrolet_compact)
m.Equation(x_subaru_compact<= 90000*y_subaru_compact)
m.Equation(x_toyota_compact<= 90000*y_toyota_compact)
    
m.Equation(x_audi_midsize <= y_audi_midsize*90000)
m.Equation(x_honda_midsize <= y_honda_midsize*90000)
m.Equation(x_hyundai_midsize <= y_hyundai_midsize*90000)
m.Equation(x_kia_midsize <= y_kia_midsize*90000)
m.Equation(x_ford_midsize <= y_ford_midsize*90000)
m.Equation(x_subaru_midsize <= y_subaru_midsize*90000)
m.Equation(x_mazda_midsize <= y_mazda_midsize*90000)
m.Equation(x_volkswagen_midsize <= y_volkswagen_midsize*90000)
m.Equation(x_toyota_midsize <= y_toyota_midsize*90000)
m.Equation(x_acura_midsize <= y_acura_midsize*90000)
m.Equation(x_volvo_midsize <= y_volvo_midsize*90000)
m.Equation(x_nissan_midsize <= y_nissan_midsize*90000)
m.Equation(x_lexus_midsize <= y_lexus_midsize *90000)

m.Equation(x_honda_suv <= 90000*y_honda_suv)
m.Equation(x_subaru_suv <= 90000*y_subaru_suv)
m.Equation(x_mazda_suv <= 90000*y_mazda_suv)
m.Equation(x_ford_suv <= 90000*y_ford_suv)
m.Equation(x_kia_suv <= 90000*y_kia_suv)
m.Equation(x_hyundai_suv <= 90000*y_hyundai_suv)
m.Equation(x_acura_suv <= 90000*y_acura_suv)
m.Equation(x_lexus_suv <= 90000*y_lexus_suv)
m.Equation(x_audi_suv <= 90000*y_audi_suv)
m.Equation(x_toyota_suv <= 90000*y_toyota_suv)
m.Equation(x_nissan_suv <= 90000*y_nissan_suv)
m.Equation(x_gmc_suv <= 90000*y_gmc_suv)
m.Equation(x_volkswagen_suv <= 90000*y_volkswagen_suv)
m.Equation(x_bmw_suv <= 90000*y_bmw_suv)
m.Equation(x_volvo_suv <= 90000*y_volvo_suv)

# When number is other than 0 for x, then y will be 1. 0 otherwise.
m.Equation(y_bmw_compact <= x_bmw_compact)
m.Equation(y_audi_compact <= x_audi_compact)
m.Equation(y_hyundai_compact <= x_hyundai_compact)
m.Equation(y_mercedes_compact <= x_mercedes_compact)
m.Equation(y_honda_compact <= x_honda_compact)
m.Equation(y_acura_compact <= x_acura_compact)
m.Equation(y_lexus_compact <= x_lexus_compact)
m.Equation(y_volkswagen_compact <= x_volkswagen_compact)
m.Equation(y_mazda_compact <= x_mazda_compact)
m.Equation(y_nissan_compact <= x_nissan_compact)
m.Equation(y_kia_compact <= x_kia_compact)
m.Equation(y_volvo_compact <= x_volvo_compact)
m.Equation(y_chevrolet_compact <= x_chevrolet_compact)
m.Equation(y_subaru_compact<= x_subaru_compact)
m.Equation(y_toyota_compact<= x_toyota_compact)
    
m.Equation(y_audi_midsize <= x_audi_midsize)
m.Equation(y_honda_midsize <= x_honda_midsize)
m.Equation(y_hyundai_midsize <= x_hyundai_midsize)
m.Equation(y_kia_midsize <= x_kia_midsize)
m.Equation(y_ford_midsize <= x_ford_midsize)
m.Equation(y_subaru_midsize <= x_subaru_midsize)
m.Equation(y_mazda_midsize <= x_mazda_midsize)
m.Equation(y_volkswagen_midsize <= x_volkswagen_midsize)
m.Equation(y_toyota_midsize <= x_toyota_midsize)
m.Equation(y_acura_midsize <= x_acura_midsize)
m.Equation(y_volvo_midsize <= x_volvo_midsize)
m.Equation(y_nissan_midsize <= x_nissan_midsize)
m.Equation(y_lexus_midsize <= x_lexus_midsize)

m.Equation(y_honda_suv <= x_honda_suv)
m.Equation(y_subaru_suv <= x_subaru_suv)
m.Equation(y_mazda_suv <= x_mazda_suv)
m.Equation(y_ford_suv <= x_ford_suv)
m.Equation(y_kia_suv <= x_kia_suv)
m.Equation(y_hyundai_suv <= x_hyundai_suv)
m.Equation(y_acura_suv <= x_acura_suv)
m.Equation(y_lexus_suv <= x_lexus_suv)
m.Equation(y_audi_suv <= x_audi_suv)
m.Equation(y_toyota_suv <= x_toyota_suv)
m.Equation(y_nissan_suv <= x_nissan_suv)
m.Equation(y_gmc_suv <= x_gmc_suv)
m.Equation(y_volkswagen_suv <= x_volkswagen_suv)
m.Equation(y_bmw_suv <= x_bmw_suv)
m.Equation(y_volvo_suv <= x_volvo_suv)


# Minimum and maximum distance a car is expected to be driven per year. 
m.Equation(-d_bmw_compact <= -30000*y_bmw_compact)  
m.Equation(-d_audi_compact <= -30000*y_audi_compact)     
m.Equation(-d_hyundai_compact <= -30000*y_hyundai_compact)   
m.Equation(-d_mercedes_compact <= -30000*y_mercedes_compact)   
m.Equation(-d_honda_compact <= -30000*y_honda_compact)   
m.Equation(-d_acura_compact <= -30000*y_acura_compact)  
m.Equation(-d_lexus_compact <= -30000*y_lexus_compact)  
m.Equation(-d_volkswagen_compact <= -30000*y_volkswagen_compact)  
m.Equation(-d_mazda_compact <= -30000*y_mazda_compact)  
m.Equation(-d_nissan_compact <= -30000*y_nissan_compact)  
m.Equation(-d_kia_compact<= -30000*y_kia_compact)   
m.Equation(-d_volvo_compact <= -30000*y_volvo_compact)  
m.Equation(-d_chevrolet_compact <= -30000*y_chevrolet_compact)  
m.Equation(-d_subaru_compact <= -30000*y_subaru_compact)  
m.Equation(-d_toyota_compact <= -30000*y_toyota_compact)  

m.Equation(d_bmw_compact <= 100000*y_bmw_compact)  
m.Equation(d_audi_compact <= 100000*y_audi_compact)     
m.Equation(d_hyundai_compact <= 100000*y_hyundai_compact)   
m.Equation(d_mercedes_compact <= 100000*y_mercedes_compact)   
m.Equation(d_honda_compact <= 100000*y_honda_compact)   
m.Equation(d_acura_compact <= 100000*y_acura_compact)  
m.Equation(d_lexus_compact <= 100000*y_lexus_compact)  
m.Equation(d_volkswagen_compact <= 100000*y_volkswagen_compact)  
m.Equation(d_mazda_compact <= 100000*y_mazda_compact)  
m.Equation(d_nissan_compact <= 100000*y_nissan_compact)  
m.Equation(d_kia_compact<= 100000*y_kia_compact)   
m.Equation(d_volvo_compact <= 100000*y_volvo_compact)  
m.Equation(d_chevrolet_compact <= 100000*y_chevrolet_compact)  
m.Equation(d_subaru_compact <= 100000*y_subaru_compact)  
m.Equation(d_toyota_compact <= 100000*y_toyota_compact)

m.Equation(-d_audi_midsize <= -30000*y_audi_midsize)
m.Equation(-d_honda_midsize <= -30000*y_honda_midsize)
m.Equation(-d_hyundai_midsize <= -30000*y_hyundai_midsize)
m.Equation(-d_kia_midsize <= -30000*y_kia_midsize)
m.Equation(-d_ford_midsize <= -30000*y_ford_midsize)
m.Equation(-d_subaru_midsize <= -30000*y_subaru_midsize)
m.Equation(-d_mazda_midsize <= -30000*y_mazda_midsize) 
m.Equation(-d_volkswagen_midsize <= -30000*y_volkswagen_midsize)
m.Equation(-d_toyota_midsize <= -30000*y_toyota_midsize)
m.Equation(-d_acura_midsize <= -30000*y_acura_midsize)
m.Equation(-d_volvo_midsize <= -30000*y_volvo_midsize)
m.Equation(-d_nissan_midsize <= -30000*y_nissan_midsize)
m.Equation(-d_lexus_midsize <= -30000*y_lexus_midsize) 

m.Equation(d_audi_midsize <= 100000*y_audi_midsize)
m.Equation(d_honda_midsize <= 100000*y_honda_midsize)
m.Equation(d_hyundai_midsize <= 100000*y_hyundai_midsize)
m.Equation(d_kia_midsize <= 100000*y_kia_midsize)
m.Equation(d_ford_midsize <= 100000*y_ford_midsize)
m.Equation(d_subaru_midsize <= 100000*y_subaru_midsize)
m.Equation(d_mazda_midsize<= 100000*y_mazda_midsize) 
m.Equation(d_volkswagen_midsize<= 100000*y_volkswagen_midsize)
m.Equation(d_toyota_midsize<= 100000*y_toyota_midsize)
m.Equation(d_acura_midsize<= 100000*y_acura_midsize)
m.Equation(d_volvo_midsize <= 100000*y_volvo_midsize)
m.Equation(d_nissan_midsize<= 100000*y_nissan_midsize)
m.Equation(d_lexus_midsize<= 100000*y_lexus_midsize) 

m.Equation(-d_honda_suv <= -30000*y_honda_suv) 
m.Equation(-d_subaru_suv <= -30000*y_subaru_suv) 
m.Equation(-d_mazda_suv <= -30000*y_mazda_suv) 
m.Equation(-d_ford_suv <= -30000*y_ford_suv) 
m.Equation(-d_kia_suv <= -30000*y_kia_suv) 
m.Equation(-d_hyundai_suv <= -30000*y_hyundai_suv) 
m.Equation(-d_acura_suv <= -30000*y_acura_suv) 
m.Equation(-d_lexus_suv <= -30000*y_lexus_suv) 
m.Equation(-d_audi_suv <= -30000*y_audi_suv) 
m.Equation(-d_toyota_suv <= -30000*y_toyota_suv) 
m.Equation(-d_nissan_suv <= -30000*y_nissan_suv) 
m.Equation(-d_gmc_suv <= -30000*y_gmc_suv) 
m.Equation(-d_volkswagen_suv <= -30000*y_volkswagen_suv) 
m.Equation(-d_bmw_suv <= -30000*y_bmw_suv) 
m.Equation(-d_volvo_suv <= -30000*y_volvo_suv) 

m.Equation(d_honda_suv <= 100000*y_honda_suv) 
m.Equation(d_subaru_suv <= 100000*y_subaru_suv)  
m.Equation(d_mazda_suv <= 100000*y_mazda_suv) 
m.Equation(d_ford_suv <= 100000*y_ford_suv) 
m.Equation(d_kia_suv <= 100000*y_kia_suv) 
m.Equation(d_hyundai_suv <= 100000*y_hyundai_suv) 
m.Equation(d_acura_suv <= 100000*y_acura_suv) 
m.Equation(d_lexus_suv<= 100000*y_lexus_suv) 
m.Equation(d_audi_suv <= 100000*y_audi_suv) 
m.Equation(d_toyota_suv <= 100000*y_toyota_suv) 
m.Equation(d_nissan_suv <= 100000*y_nissan_suv) 
m.Equation(d_gmc_suv <= 100000*y_gmc_suv) 
m.Equation(d_volkswagen_suv <= 100000*y_volkswagen_suv) 
m.Equation(d_bmw_suv <= 100000*y_bmw_suv) 
m.Equation(d_volvo_suv<= 100000*y_volvo_suv)

# Minimum number of car types for each class the company wants to lease. Atleast 5 of each vehicle class.
m.Equation(-ycompact <= -5)
m.Equation(-ymidsize <= -5)
m.Equation(-ysuv <= -5)

# %% [markdown]
# ## Objective function = Max profit = Revenue - Leasing Cost - Fuel Cost - Salary

# %% [markdown]
# #### Objective function for Scenario 1 mentioned in the project report is "m.Obj(emission)." Minimizing CO2 Emission

# %%
# Must put negative sign on objective function for maximizing.
m.Obj(-profit)

# %%
# Solve model
m.solve()
# Out:
# apm 184.146.8.140_gk_model0 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
# ...
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :          351
#    Intermediates:            0
#    Connections  :            0
#    Equations    :          223
#    Residuals    :          223
#
#  Number of state variables:            351
#  Number of total equations: -          222
#  Number of slack variables: -          222
#  ---------------------------------------
#  Degrees of freedom       :            -93
#
#  * Warning: DOF <= 0
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# ...

# %% [markdown]
# # Results

# %%
# Optimal Solution

print('x_bmw_compact:', x_bmw_compact.value,',', 'd_bmw_compact:', d_bmw_compact.value,',', 'y_bmw_compact:', y_bmw_compact.value)
print('x_audi_compact:', x_audi_compact.value,',', 'd_audi_compact:', d_audi_compact.value,',', 'y_audi_compact:', y_audi_compact.value)
print('x_hyundai_compact: ',x_hyundai_compact.value,',', 'd_hyundai_compact:', d_hyundai_compact.value,',', 'y_hyundai_compact:', y_hyundai_compact.value)
print('x_mercedes_compact: ',x_mercedes_compact.value,',', 'd_mercedes_compact:', d_mercedes_compact.value,',', 'y_mercedes_compact:', y_mercedes_compact.value)
print('x_honda_compact: ',x_honda_compact.value,',', 'd_honda_compact:', d_honda_compact.value,',', 'y_honda_compact:', y_honda_compact.value)
print('x_acura_compact: ',x_acura_compact.value,',', 'd_acura_compact:', d_acura_compact.value,',', 'y_acura_compact:', y_acura_compact.value)
print('x_lexus_compact: ',x_lexus_compact.value,',', 'd_lexus_compact:', d_lexus_compact.value,',', 'y_lexus_compact:', y_lexus_compact.value)
print('x_volkswagen_compact: ',x_volkswagen_compact.value,',', 'd_volkswagen_compact:', d_volkswagen_compact.value,',', 'y_volkswagen_compact:', y_volkswagen_compact.value)
print('x_mazda_compact: ',x_mazda_compact.value,',', 'd_mazda_compact:', d_mazda_compact.value,',', 'y_mazda_compact:', y_mazda_compact.value)
print('x_nissan_compact: ',x_nissan_compact.value,',', 'd_nissan_compact:', d_nissan_compact.value,',', 'y_nissan_compact:', y_nissan_compact.value)
print('x_kia_compact: ',x_kia_compact.value,',', 'd_kia_compact:', d_kia_compact.value,',', 'y_kia_compact:', y_kia_compact.value)
print('x_volvo_compact: ',x_volvo_compact.value,',', 'd_volvo_compact:', d_volvo_compact.value,',', 'y_volvo_compact:', y_volvo_compact.value)
print('x_chevrolet_compact: ',x_chevrolet_compact.value,',', 'd_chevrolet_compact:', d_chevrolet_compact.value,',', 'y_chevrolet_compact:', y_chevrolet_compact.value)
print('x_subaru_compact: ',x_subaru_compact.value,',', 'd_subaru_compact:', d_subaru_compact.value,',', 'y_subaru_compact:', y_subaru_compact.value)
print('x_toyota_compact: ',x_toyota_compact.value,',', 'd_toyota_compact:', d_toyota_compact.value,',', 'y_toyota_compact:', y_toyota_compact.value)

print('x_audi_midsize:',x_audi_midsize.value,',', 'd_audi_midsize:',d_audi_midsize.value,',', 'y_audi_midsize:',y_audi_midsize.value)
print('x_honda_midsize:',x_honda_midsize.value,',', 'd_honda_midsize:',d_honda_midsize.value,',', 'y_honda_midsize:',y_honda_midsize.value)
print('x_hyundai_midsize:',x_hyundai_midsize.value,',', 'd_hyundai_midsize:',d_hyundai_midsize.value,',', 'y_hyundai_midsize:',y_hyundai_midsize.value)
print('x_kia_midsize:',x_kia_midsize.value,',','d_kia_midsize:',d_kia_midsize.value ,',','y_kia_midsize:',y_kia_midsize.value)
print('x_ford_midsize:',x_ford_midsize.value,',', 'd_ford_midsize:',d_ford_midsize.value,',', 'y_ford_midsize:',y_ford_midsize.value)
print('x_subaru_midsize:',x_subaru_midsize.value,',', 'd_subaru_midsize:',d_subaru_midsize.value,',', 'y_subaru_midsize:',y_subaru_midsize.value)
print('x_mazda_midsize:',x_mazda_midsize.value,',', 'd_mazda_midsize:',d_mazda_midsize.value,',', 'y_mazda_midsize:',y_mazda_midsize.value)
print('x_volkswagen_midsize:',x_volkswagen_midsize.value,',', 'd_volkswagen_midsize:',d_volkswagen_midsize.value,',', 'y_volkswagen_midsize:',y_volkswagen_midsize.value)
print('x_toyota_midsize:',x_toyota_midsize.value,',', 'd_toyota_midsize:',d_toyota_midsize.value,',', 'y_toyota_midsize:',y_toyota_midsize.value)
print('x_acura_midsize:',x_acura_midsize.value,',', 'd_acura_midsize:',d_acura_midsize.value,',', 'y_acura_midsize:',y_acura_midsize.value)
print('x_volvo_midsize:',x_volvo_midsize.value,',', 'd_volvo_midsize:',d_volvo_midsize.value,',', 'y_volvo_midsize:',y_volvo_midsize.value)
print('x_nissan_midsize:',x_nissan_midsize.value,',', 'd_nissan_midsize:',d_nissan_midsize.value,',', 'y_nissan_midsize:',y_nissan_midsize.value)
print('x_lexus_midsize:',x_lexus_midsize.value,',', 'd_lexus_midsize:',d_lexus_midsize.value,',', 'y_lexus_midsize:',y_lexus_midsize.value)

print("x_honda_suv",x_honda_suv.value,',', "d_honda_suv:",d_honda_suv.value,',', "y_honda_suv:", y_honda_suv.value )
print("x_subaru_suv",x_subaru_suv.value,',', "d_subaru_suv:",d_subaru_suv.value,',', "y_subaru_suv:", y_subaru_suv.value  )
print("x_mazda_suv",x_mazda_suv.value,',', "d_mazda_suv:",d_mazda_suv.value,',', "y_mazda_suv:", y_mazda_suv.value  )
print("x_ford_suv",x_ford_suv.value,',', "d_ford_suv:",d_ford_suv.value,',', "y_ford_suv:", y_ford_suv.value  )
print("x_kia_suv",x_kia_suv.value,',', "d_kia_suv:",d_kia_suv.value,',', "y_kia_suv:", y_kia_suv.value  )
print("x_hyundai_suv",x_hyundai_suv.value,',', "d_hyundai_suv:",d_hyundai_suv.value,',', "y_hyundai_suv:", y_hyundai_suv.value  )
print("x_acura_suv",x_acura_suv.value,',', "d_acura_suv:",d_acura_suv.value,',', "y_acura_suv:", y_acura_suv.value  )
print("x_lexus_suv",x_lexus_suv.value,',', "d_lexus_suv:",d_lexus_suv.value,',', "y_lexus_suv:", y_lexus_suv.value  )
print("x_audi_suv",x_audi_suv.value,',', "d_audi_suv:",d_audi_suv.value,',', "y_audi_suv:", y_audi_suv.value  )
print("x_toyota_suv", x_toyota_suv.value,',', "d_toyota_suv:",d_toyota_suv.value,',', "y_toyota_suv:", y_toyota_suv.value )
print("x_nissan_suv",x_nissan_suv.value,',', "d_nissan_suv:",d_nissan_suv.value,',', "y_nissan_suv:", y_nissan_suv.value  )
print("x_gmc_suv",x_gmc_suv.value,',', "d_gmc_suv:",d_gmc_suv.value,',', "y_gmc_suv:", y_gmc_suv.value  )
print("x_volkswagen_suv", x_volkswagen_suv.value,',', "d_volkswagen_suv:",d_volkswagen_suv.value,',', "y_volkswagen_suv:", y_volkswagen_suv.value )
print("x_bmw_suv",x_bmw_suv.value,',', "d_bmw_suv:",d_bmw_suv.value,',', "y_bmw_suv:", y_bmw_suv.value  )
print("x_volvo_suv",x_volvo_suv.value,',', "d_volvo_suv:",d_volvo_suv.value,',', "y_volvo_suv:", y_volvo_suv.value  )

print('\n')
print("Max Profit:", m.options.OBJFCNVAL*-1) # May give a strange result. Therefore, calculated manually through Excel.
# Out:
# x_bmw_compact: [0.0] , d_bmw_compact: [0.0] , y_bmw_compact: [0.0]
# x_audi_compact: [0.0] , d_audi_compact: [0.0] , y_audi_compact: [0.0]
# x_hyundai_compact:  [5.0] , d_hyundai_compact: [30000.0] , y_hyundai_compact: [1.0]
# x_mercedes_compact:  [0.0] , d_mercedes_compact: [0.0] , y_mercedes_compact: [0.0]
# x_honda_compact:  [5.0] , d_honda_compact: [100000.0] , y_honda_compact: [1.0]
# x_acura_compact:  [5.0] , d_acura_compact: [100000.0] , y_acura_compact: [1.0]
# x_lexus_compact:  [0.0] , d_lexus_compact: [0.0] , y_lexus_compact: [0.0]
# x_volkswagen_compact:  [4.0] , d_volkswagen_compact: [30000.0] , y_volkswagen_compact: [1.0]
# x_mazda_compact:  [0.0] , d_mazda_compact: [0.0] , y_mazda_compact: [0.0]
# x_nissan_compact:  [0.0] , d_nissan_compact: [0.0] , y_nissan_compact: [0.0]
# x_kia_compact:  [0.0] , d_kia_compact: [0.0] , y_kia_compact: [0.0]
# x_volvo_compact:  [0.0] , d_volvo_compact: [0.0] , y_volvo_compact: [0.0]
# ...

# %%
# Create dataframe

import pandas as pd

data = {'Xij': [x_bmw_compact.value, x_audi_compact.value, x_hyundai_compact.value , x_mercedes_compact.value , x_honda_compact.value,  x_acura_compact.value,  x_lexus_compact.value , x_volkswagen_compact.value , x_mazda_compact.value , x_nissan_compact.value , x_kia_compact.value,  x_volvo_compact.value, x_chevrolet_compact.value, x_subaru_compact.value, x_toyota_compact.value, x_audi_midsize.value, x_honda_midsize.value, x_hyundai_midsize.value, x_kia_midsize.value, x_ford_midsize.value, x_subaru_midsize.value, x_mazda_midsize.value, x_volkswagen_midsize.value, x_toyota_midsize.value, x_acura_midsize.value, x_volvo_midsize.value, x_nissan_midsize.value, x_lexus_midsize.value, x_honda_suv.value, x_subaru_suv.value, x_mazda_suv.value, x_ford_suv.value, x_kia_suv.value, x_hyundai_suv.value, x_acura_suv.value, x_lexus_suv.value, x_audi_suv.value, x_toyota_suv.value, x_nissan_suv.value, x_gmc_suv.value, x_volkswagen_suv.value, x_bmw_suv.value, x_volvo_suv.value],
       'Dij':[d_bmw_compact.value, d_audi_compact.value, d_hyundai_compact.value , d_mercedes_compact.value , d_honda_compact.value,  d_acura_compact.value,  d_lexus_compact.value , d_volkswagen_compact.value , d_mazda_compact.value , d_nissan_compact.value , d_kia_compact.value,  d_volvo_compact.value, d_chevrolet_compact.value, d_subaru_compact.value, d_toyota_compact.value, d_audi_midsize.value, d_honda_midsize.value, d_hyundai_midsize.value, d_kia_midsize.value, d_ford_midsize.value, d_subaru_midsize.value, d_mazda_midsize.value, d_volkswagen_midsize.value, d_toyota_midsize.value, d_acura_midsize.value, d_volvo_midsize.value, d_nissan_midsize.value, d_lexus_midsize.value, d_honda_suv.value, d_subaru_suv.value, d_mazda_suv.value, d_ford_suv.value, d_kia_suv.value, d_hyundai_suv.value, d_acura_suv.value, d_lexus_suv.value, d_audi_suv.value, d_toyota_suv.value, d_nissan_suv.value, d_gmc_suv.value, d_volkswagen_suv.value, d_bmw_suv.value, d_volvo_suv.value],
              'Yij':[y_bmw_compact.value, y_audi_compact.value, y_hyundai_compact.value , y_mercedes_compact.value , y_honda_compact.value,  y_acura_compact.value,  y_lexus_compact.value , y_volkswagen_compact.value , y_mazda_compact.value , y_nissan_compact.value , y_kia_compact.value,  y_volvo_compact.value, y_chevrolet_compact.value, y_subaru_compact.value, y_toyota_compact.value, y_audi_midsize.value, y_honda_midsize.value, y_hyundai_midsize.value, y_kia_midsize.value, y_ford_midsize.value, y_subaru_midsize.value, y_mazda_midsize.value, y_volkswagen_midsize.value, y_toyota_midsize.value, y_acura_midsize.value, y_volvo_midsize.value, y_nissan_midsize.value, y_lexus_midsize.value, y_honda_suv.value, y_subaru_suv.value, y_mazda_suv.value, y_ford_suv.value, y_kia_suv.value, y_hyundai_suv.value, y_acura_suv.value, y_lexus_suv.value, y_audi_suv.value, y_toyota_suv.value, y_nissan_suv.value, y_gmc_suv.value, y_volkswagen_suv.value, y_bmw_suv.value, y_volvo_suv.value]}

dframe = pd.DataFrame(data, index=['x_bmw_compact', 'x_audi_compact', 'x_hyundai_compact', 'x_mercedes_compact', 'x_honda_compact' , 'x_acura_compact', 'x_lexus_compact', 'x_volkswagen_compact', 'x_mazda_compact' , 'x_nissan_compact', 'x_kia_compact', 'x_volvo_compact', 'x_chevrolet_compact', 'x_subaru_compact', 'x_toyota_compact', 'x_audi_midsize', 'x_honda_midsize', 'x_hyundai_midsize', 'x_kia_midsize', 'x_ford_midsize', 'x_subaru_midsize', 'x_mazda_midsize', 'x_volkswagen_midsize', 'x_toyota_midsize', 'x_acura_midsize', 'x_volvo_midsize', 'x_nissan_midsize', 'x_lexus_midsize', 'x_honda_suv', 'x_subaru_suv', 'x_mazda_suv','x_ford_suv', 'x_kia_suv', 'x_hyundai_suv', 'x_acura_suv', 'x_lexus_suv', 'x_audi_suv', 'x_toyota_suv', 'x_nissan_suv', 'x_gmc_suv', 'x_volkswagen_suv', 'x_bmw_suv', 'x_volvo_suv'])

# Save to Excel
dframe.to_excel("Model Solution.xlsx")

# %% [markdown]
# ### Visually comparing the maximum profit obtained from each scenario to the base-case model. Represented as Figure 10 of the report.

# %%
# Packages needed for graphing 
import matplotlib.pyplot as plt
import seaborn as sns

# set background of graph
sns.set_style('darkgrid')

# %matplotlib inline

# scenarios and their maximum profits
x = ['2.i','2.ii','3.i','3.ii','4.i','4.ii','5','6']
y = [11486752.20, 2178981.94,1060290.41,613576.62,921868.26,789399.74,2159541.23,1481866.28]


plt.figure(figsize=(14,10)) # graph size

ax = sns.barplot(x,y) # bar plot of max profit in a year for each scenario

# labelling 
plt.xlabel('Scenario')
plt.ylabel('Maximum Profit per Year ($)')
plt.axhline(988638.17, color='r',ls='--', label='Base-Case Model = $988,638.17') # Red dashing boundary line for comparison

# show the exact value of the maximum profit on top of each bar 
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()), ha='center', color='black', size=15)

plt.ylim(100000,12000000)

plt.legend() # Legend to show that the maximum profit of the base model at $988,638.17

plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
# pulling out the dataset from Statistics Canada

dataframe = pd.read_csv('Group-1-CO2_Emission_Cost_ProjectData2020.csv')

# %%
# Relationship between CO2 Emission and features of car 2020 (Figure 1)

fig = plt.figure(figsize=(15,20))


ax1 = fig.add_subplot(421)
ax1.set_xlabel('Engine Size (L)')
ax1.set_ylabel('CO2 Emission (g/km)')
sns.scatterplot(data = dataframe, x = 'Engine Size (L)', y = 'CO2 Emissions (g/km)')

ax2 = fig.add_subplot(422)
ax2.set_xlabel('Cylinders')
ax2.set_ylabel('CO2 Emission (g/km)')
sns.scatterplot(x = 'Cylinders', y = 'CO2 Emissions (g/km)', data = dataframe)

ax3 = fig.add_subplot(423)
ax3.set_xlabel('Fuel Consumption Highway (L/100 km)')
ax3.set_ylabel('CO2 Emissions (g/km)')
sns.scatterplot(x = 'Fuel Consumption Highway (L/100 km)', y = 'CO2 Emissions (g/km)', data = dataframe)

ax4 = fig.add_subplot(424)
ax4.set_xlabel('Combined (L/100km)')
ax4.set_ylabel('CO2 Emissions (g/km)')
sns.scatterplot(x = 'Combined (L/100 km)', y = 'CO2 Emissions (g/km)', data = dataframe)

ax5 = fig.add_subplot(425)
ax5.set_xlabel('Fuel Consumption City (L/100 km)')
ax5.set_ylabel('CO2 Emissions (g/km)')
sns.scatterplot(x = 'Fuel Consumption City (L/100 km)', y = 'CO2 Emissions (g/km)', data = dataframe)

ax6 = fig.add_subplot(426)
ax6.set_xlabel('CO2 Rating')
ax6.set_ylabel('CO2 Emissions (g/km)')
sns.scatterplot(x = 'CO2 Rating', y = 'CO2 Emissions (g/km)', data = dataframe)

ax7 = fig.add_subplot(427)
sns.scatterplot(x = 'yearly_lease_price', y = 'CO2 Emissions (g/km)', data = dataframe)

plt.show()

# %%
# Relationship between Fuel cost per year and features of car 2020 (Figure 2)

fig = plt.figure(figsize=(15,20))


ax1 = fig.add_subplot(421)
ax1.set_xlabel('Engine Size (L)')
ax1.set_ylabel('Annual Fuel Cost')
sns.scatterplot(data = dataframe, x = 'Engine Size (L)', y = 'Fuel CostPerYear')

ax2 = fig.add_subplot(422)
ax2.set_xlabel('Cylinders')
ax2.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Cylinders', y = 'Fuel CostPerYear', data = dataframe)

ax3 = fig.add_subplot(423)
ax3.set_xlabel('Fuel Consumption Highway (L/100 km)')
ax3.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Fuel Consumption Highway (L/100 km)', y = 'Fuel CostPerYear', data = dataframe)

ax4 = fig.add_subplot(424)
ax4.set_xlabel('Combined (L/100km)')
ax4.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Combined (L/100 km)', y = 'Fuel CostPerYear', data = dataframe)

ax5 = fig.add_subplot(425)
ax5.set_xlabel('Fuel Consumption City (L/100 km)')
ax5.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Fuel Consumption City (L/100 km)', y = 'Fuel CostPerYear', data = dataframe)

ax6 = fig.add_subplot(426)
ax6.set_xlabel('CO2 Rating')
ax6.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'CO2 Rating', y = 'Fuel CostPerYear', data = dataframe)

ax7 = fig.add_subplot(427)
sns.scatterplot(x = 'yearly_lease_price', y = 'Fuel CostPerYear', data = dataframe)

plt.show()

# %%
# Relationship of CO2 Rating and Car Features (2020) (Figure 3)

fig = plt.figure(figsize=(15,20))


ax1 = fig.add_subplot(421)
ax1.set_xlabel('Engine Size (L)')
ax1.set_ylabel('CO2 Rating')
sns.scatterplot(data = dataframe, x = 'Engine Size (L)', y = 'CO2 Rating')

ax2 = fig.add_subplot(422)
ax2.set_xlabel('Cylinders')
sns.scatterplot(x = 'Cylinders', y = 'CO2 Rating', data = dataframe)

ax3 = fig.add_subplot(423)
ax3.set_xlabel('Fuel Consumption Highway (L/100 km)')
sns.scatterplot(x = 'Fuel Consumption Highway (L/100 km)', y = 'CO2 Rating', data = dataframe)

ax4 = fig.add_subplot(424)
ax4.set_xlabel('Combined (L/100km)')
sns.scatterplot(x = 'Combined (L/100 km)', y = 'CO2 Rating', data = dataframe)

ax5 = fig.add_subplot(425)
ax5.set_xlabel('Fuel Consumption City (L/100 km)')
sns.scatterplot(x = 'Fuel Consumption City (L/100 km)', y = 'CO2 Rating', data = dataframe)

ax6 = fig.add_subplot(426)
ax6.set_xlabel('CO2 Emissions (g/km)')
sns.scatterplot(x = 'CO2 Emissions (g/km)', y = 'CO2 Rating', data = dataframe)

ax7 = fig.add_subplot(427)
sns.scatterplot(x = 'yearly_lease_price', y = 'CO2 Rating', data = dataframe)
ax7.set_xlabel('Lease Price')

plt.show()

# %%
# Regular Fuel - Linear relationship between Fuel cost per year and features of car 2020 (Figure 4)

dfx = dataframe[dataframe['Fuel Type'] == 'X']

fig = plt.figure(figsize=(15,20))


ax1 = fig.add_subplot(421)
ax1.set_xlabel('Engine Size (L)')
ax1.set_ylabel('Annual Fuel Cost')
sns.scatterplot(data = dfx, x = 'Engine Size (L)', y = 'Fuel CostPerYear')

ax2 = fig.add_subplot(422)
ax2.set_xlabel('Cylinders')
ax2.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Cylinders', y = 'Fuel CostPerYear', data = dfx)

ax3 = fig.add_subplot(423)
ax3.set_xlabel('Fuel Consumption Highway (L/100 km)')
ax3.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Fuel Consumption Highway (L/100 km)', y = 'Fuel CostPerYear', data = dfx)

ax4 = fig.add_subplot(424)
ax4.set_xlabel('Combined (L/100km)')
ax4.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Combined (L/100 km)', y = 'Fuel CostPerYear', data = dfx)

ax5 = fig.add_subplot(425)
ax5.set_xlabel('Fuel Consumption City (L/100 km)')
ax5.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Fuel Consumption City (L/100 km)', y = 'Fuel CostPerYear', data = dfx)

ax6 = fig.add_subplot(426)
ax6.set_xlabel('CO2 Rating')
ax6.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'CO2 Rating', y = 'Fuel CostPerYear', data = dfx)

ax7 = fig.add_subplot(427)
sns.scatterplot(x = 'yearly_lease_price', y = 'Fuel CostPerYear', data = dfx)

plt.show()

# %%
# Fuel Type Z - Linear relationship between Fuel cost per year and features of car 2020 (Figure 5)

dfz = dataframe[dataframe['Fuel Type'] == 'Z']

fig = plt.figure(figsize=(15,20))


ax1 = fig.add_subplot(421)
ax1.set_xlabel('Engine Size (L)')
ax1.set_ylabel('Annual Fuel Cost')
sns.scatterplot(data = dfz, x = 'Engine Size (L)', y = 'Fuel CostPerYear')

ax2 = fig.add_subplot(422)
ax2.set_xlabel('Cylinders')
ax2.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Cylinders', y = 'Fuel CostPerYear', data = dfz)

ax3 = fig.add_subplot(423)
ax3.set_xlabel('Fuel Consumption Highway (L/100 km)')
ax3.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Fuel Consumption Highway (L/100 km)', y = 'Fuel CostPerYear', data = dfz)

ax4 = fig.add_subplot(424)
ax4.set_xlabel('Combined (L/100km)')
ax4.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Combined (L/100 km)', y = 'Fuel CostPerYear', data = dfz)

ax5 = fig.add_subplot(425)
ax5.set_xlabel('Fuel Consumption City (L/100 km)')
ax5.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'Fuel Consumption City (L/100 km)', y = 'Fuel CostPerYear', data = dfz)

ax6 = fig.add_subplot(426)
ax6.set_xlabel('CO2 Rating')
ax6.set_ylabel('Annual Fuel Cost')
sns.scatterplot(x = 'CO2 Rating', y = 'Fuel CostPerYear', data = dfz)

ax7 = fig.add_subplot(427)
sns.scatterplot(x = 'yearly_lease_price', y = 'Fuel CostPerYear', data = dfz)

plt.show()

# %%
# Relationship between leasing price and CO2 emission (Figure 6)
sns.scatterplot(data = dataframe, x = 'CO2 Emissions (g/km)', y = 'yearly_lease_price')

# %%
# Comparison between fuel types and their annual fuel cost vs. CO2 emission (Figure 7)

sns.scatterplot(data = dfx, x = 'CO2 Emissions (g/km)', y = 'Fuel CostPerYear', label = 'Regular Fuel')
sns.scatterplot(data = dfz, x = 'CO2 Emissions (g/km)', y = 'Fuel CostPerYear', label = 'Premium Fuel')

# %%
# Histogram of the CO2 Emission of cars (Figure 8)

plt.figure(figsize=(10,5))

plt.hist(dataframe['CO2 Emissions (g/km)'], bins = 10)

plt.title('Histogram - CO2 Emissions (2020)')
plt.xlabel('CO2 Emissions (g/km)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Histogram of the car prices paid in full. This determined that the company should focus on cars that cost less than $75k
# Figure 9

plt.figure(figsize=(10,5))

plt.hist(dataframe['full PRICE (w/o tax)'], bins = 10)

plt.title('Histogram - Price of Car')
plt.xlabel('Car Price $')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
